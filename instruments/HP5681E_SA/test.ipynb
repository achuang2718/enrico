# %%
import pyvisa 
import numpy as np 
import matplotlib.pyplot as plt
from simplevisa import HP8561B


device = HP8561B(0, 18)

# %%
device.setCenter(1.5, 'GHz')
device.setSpan(10, 'MHz')
device.setRBW(10, 'kHz')
# Out:
# CF 1.5GHz
# SP 10MHz
# RB 10kHz

# %%
device.get_center()
# Out:
# 1500000000.0

# %%
trace_dict = device.get_trace(trace_label='A')

# %%
device.get_and_show_trace(trace_label='A')

# %%
max(trace_dict['level_list'])
# Out:
# -12.0
