# %%
import pyvisa 
import numpy as np 
import pyqtgraph as pg 
import matplotlib.pyplot as plt
from simplevisa import HP856x
from pyqtgraph.Qt import QtCore


device = HP856x(0, 18)
# Out:
# c:\Users\Administrator\Github\enrico\instruments\HP5681E_SA\simplevisa.py:317: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if self.queryInstrument('OUT') is 0 and enable is None:
# c:\Users\Administrator\Github\enrico\instruments\HP5681E_SA\simplevisa.py:347: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if self.queryInstrument('OUT') is 0 and enable is None:
# c:\Users\Administrator\Github\enrico\instruments\HP5681E_SA\simplevisa.py:317: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if self.queryInstrument('OUT') is 0 and enable is None:
# c:\Users\Administrator\Github\enrico\instruments\HP5681E_SA\simplevisa.py:347: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if self.queryInstrument('OUT') is 0 and enable is None:
# c:\Users\Administrator\Github\enrico\instruments\HP5681E_SA\simplevisa.py:317: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if self.queryInstrument('OUT') is 0 and enable is None:
# c:\Users\Administrator\Github\enrico\instruments\HP5681E_SA\simplevisa.py:347: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if self.queryInstrument('OUT') is 0 and enable is None:
# ---------------------------------------------------------------------------
# VisaIOError                               Traceback (most recent call last)
# Cell In[1], line 9
#       5 from simplevisa import HP856x
#       6 from pyqtgraph.Qt import QtCore
# ----> 9 device = HP856x(0, 18)
#
# File c:\Users\Administrator\Github\enrico\instruments\HP5681E_SA\simplevisa.py:40, in HP856x.__init__(self, bus, addr)
#      38 self.visaID = 'GPIB' + str(bus) + '::' + str(addr) + '::INSTR'
#      39 self.rm = pyvisa.ResourceManager()
# ---> 40 self.instance = self.rm.open_resource(str(self.visaID))
#
# File c:\ProgramData\anaconda3\envs\py38\lib\site-packages\pyvisa\highlevel.py:3292, in ResourceManager.open_resource(self, resource_name, access_mode, open_timeout, resource_pyclass, **kwargs)
#    3286     if not present:
#    3287         raise ValueError(
#    3288             "%r is not a valid attribute for type %s"
#    3289             % (key, res.__class__.__name__)
#    3290         )
# -> 3292 res.open(access_mode, open_timeout)
#    3294 for key, value in kwargs.items():
#    3295     setattr(res, key, value)
#
# File c:\ProgramData\anaconda3\envs\py38\lib\site-packages\pyvisa\resources\resource.py:281, in Resource.open(self, access_mode, open_timeout)
#     277 logger.debug("%s - opening ...", self._resource_name, extra=self._logging_extra)
#     278 with self._resource_manager.ignore_warning(
#     279     constants.StatusCode.success_device_not_present
#     280 ):
# --> 281     self.session, status = self._resource_manager.open_bare_resource(
#     282         self._resource_name, access_mode, open_timeout
#     283     )
#     285     if status == constants.StatusCode.success_device_not_present:
#     286         # The device was not ready when we opened the session.
#     287         # Now it gets five seconds more to become ready.
#     288         # Every 0.1 seconds we probe it with viClear.
#     289         start_time = time.time()
#
# File c:\ProgramData\anaconda3\envs\py38\lib\site-packages\pyvisa\highlevel.py:3217, in ResourceManager.open_bare_resource(self, resource_name, access_mode, open_timeout)
#    3188 def open_bare_resource(
#    3189     self,
#    3190     resource_name: str,
#    3191     access_mode: constants.AccessModes = constants.AccessModes.no_lock,
#    3192     open_timeout: int = constants.VI_TMO_IMMEDIATE,
#    3193 ) -> Tuple[VISASession, StatusCode]:
#    3194     """Open the specified resource without wrapping into a class.
#    3195
#    3196     Parameters
#    (...)
#    3215
#    3216     """
# -> 3217     return self.visalib.open(self.session, resource_name, access_mode, open_timeout)
#
# File c:\ProgramData\anaconda3\envs\py38\lib\site-packages\pyvisa\ctwrapper\functions.py:1850, in open(library, session, resource_name, access_mode, open_timeout)
#    1846 out_session = ViSession()
#    1848 # [ViSession, ViRsrc, ViAccessMode, ViUInt32, ViPSession]
#    1849 # ViRsrc converts from (str, unicode, bytes) to bytes
# -> 1850 ret = library.viOpen(
#    1851     session, resource_name, access_mode, open_timeout, byref(out_session)
#    1852 )
#    1853 return out_session.value, ret
#
# File c:\ProgramData\anaconda3\envs\py38\lib\site-packages\pyvisa\ctwrapper\highlevel.py:226, in IVIVisaLibrary._return_handler(self, ret_value, func, arguments)
#     223         # Set session back to a safe value
#     224         session = None
# --> 226 return self.handle_return_value(session, ret_value)
#
# File c:\ProgramData\anaconda3\envs\py38\lib\site-packages\pyvisa\highlevel.py:251, in VisaLibraryBase.handle_return_value(self, session, status_code)
#     248     self._last_status_in_session[session] = rv
#     250 if rv < 0:
# --> 251     raise errors.VisaIOError(rv)
#     253 if rv in self.issue_warning_on:
#     254     if session and rv not in self._ignore_warning_in_session[session]:
#
# VisaIOError: VI_ERROR_RSRC_NFOUND (-1073807343): Insufficient location information or the requested device or resource is not present in the system.

# %%
device.showGraph()
